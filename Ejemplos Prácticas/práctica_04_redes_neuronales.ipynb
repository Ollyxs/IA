# %% [markdown]
# # <font color='violet'> Redes neuronales artificiales </font>
#
# En este notebook veremos como implementar una red neuronal artificial usando el framework `TensorFlow`.
#
# Usaremos la versión TF2.X que posee una ejecución `eager` lo que resulta más sencillo de implementar a través de su API en Keras para Python.
#
# En este notebook veremos:
# 1. Regresión lineal simple.
# 2. Regresión lineal multivariable.
# 3. Regresión logística.
#
# Para estos casos se llevará a cabo el mismo flujo de pasos:
# * Realizamos un análisis exploratorio de datos (EDA).
# * Separamos los datos en entrenamiento, validación y testeo.
# * Construimos la arquitectura de la red neuronal.
# * Establecemos la función de costo, optimizador y métricas que controlarán todo el proceso de entrenamiento y validación.
# * Entrenamos el modelo.
# * Evaluamos el modelo.
# * Realizamos predicciones.

# %% [markdown]
# ---

# %% [markdown]
# # 1. Regresión lineal simple

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Armamos el dataset

# %%
# Para esto creamos un dataset ficticcio con sklearn
from sklearn.datasets import make_regression
X,y = make_regression(n_samples=1000, n_features=1, noise=3, random_state=42)

# %%
print(f"Variable de entrada X: {X.shape}, con dimensiones = {X.ndim} | datos tipo: {X.dtype}")
print(f"Variable de salida y: {y.shape}, con dimensiones = {y.ndim} | datos tipo: {y.dtype}")
# Out:
# Variable de entrada X: (1000, 1), con dimensiones = 2 | datos tipo: float64
# Variable de salida y: (1000,), con dimensiones = 1 | datos tipo: float64

# %% [markdown]
# ## Visualizamos el dataset

# %%
# Vamos a visualizar los datos para regresión
plt.figure(figsize=(10,7))
plt.scatter(X, y, c='orange')
plt.title("Full dataset");

# %% [markdown]
# ## Separamos el dataset
#
# Como el método de sklearn de `train_test_split` solo nos permite separar en dos el dataset, lo haremos **dos veces** para separar en train, validation y test.

# %%
from sklearn.model_selection import train_test_split
#primero separamos en val y train
Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=0.15, random_state=42)
#luego tomamos el conjunto de train y lo volvemos a separar en train y test
Xtrain, Xtest, ytrain, ytest = train_test_split(Xtrain, ytrain, test_size=0.15, random_state=42)

# %%
print(f"Datos de entrenamiento: {Xtrain.shape} | con dimensiones = {Xtrain.ndim} | datos tipo: {Xtrain.dtype}")
print(f"Datos de validacion: {Xval.shape} | con dimensiones = {Xval.ndim} | datos tipo: {Xval.dtype}")
print(f"Datos de testeo: {Xtest.shape} | con dimensiones = {Xtest.ndim} | datos tipo: {Xtest.dtype}")
# Out:
# Datos de entrenamiento: (722, 1) | con dimensiones = 2 | datos tipo: float64
# Datos de validacion: (150, 1) | con dimensiones = 2 | datos tipo: float64
# Datos de testeo: (128, 1) | con dimensiones = 2 | datos tipo: float64

# %% [markdown]
# ## Contruimos la arquitectura de la red neuronal

# %% [markdown]
# ### 1. Primera forma de construir una red

# %%
# Arquitectura de red con método Funcional de Keras
input = tf.keras.layers.Input(shape=[1])
output = tf.keras.layers.Dense(1,activation='linear')(input)

model_0_1 = tf.keras.Model(input,output)

# %% [markdown]
# ```
# input = tf.keras.layers.Input(shape=[1])
# capa_1 = tf.keras.layers.Dense(1,activation='relu')(input)
# capa_2 = tf.keras.layers.Dense(1,activation='relu')(capa_1)
# capa_3 = tf.keras.layers.Dense(1,activation='relu')(capa_2)
# output = tf.keras.layers.Dense(1,activation='linear')(capa_3)
#
# modelo = tf.keras.Model(input,output)
# ```

# %% [markdown]
# ### 2. Segunda forma de construir una red

# %%
# Arquitectura de red con método Sequential de Keras
model_0 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[1]),
    tf.keras.layers.Dense(1,activation='linear')
])

# %% [markdown]
# ## Configuramos el modelo

# %%
model_0.compile(optimizer = tf.keras.optimizers.SGD(),
                loss = tf.keras.losses.mae,
                metrics = ['mae'])
model_0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Entrenamos el modelo

# %%
history_slr = model_0.fit(Xtrain,ytrain,
                          epochs=200,
                          validation_data = (Xval,yval))
# Out:
# Epoch 1/200
# 23/23 [==============================] - 5s 10ms/step - loss: 11.7633 - mae: 11.7633 - val_loss: 12.4479 - val_mae: 12.4479
# Epoch 2/200
# 23/23 [==============================] - 0s 4ms/step - loss: 11.6357 - mae: 11.6357 - val_loss: 12.3092 - val_mae: 12.3092
# Epoch 3/200
# 23/23 [==============================] - 0s 4ms/step - loss: 11.5080 - mae: 11.5080 - val_loss: 12.1707 - val_mae: 12.1707
# Epoch 4/200
# 23/23 [==============================] - 0s 5ms/step - loss: 11.3806 - mae: 11.3806 - val_loss: 12.0320 - val_mae: 12.0320
# Epoch 5/200
# 23/23 [==============================] - 0s 5ms/step - loss: 11.2530 - mae: 11.2530 - val_loss: 11.8926 - val_mae: 11.8926
# Epoch 6/200
# 23/23 [==============================] - 0s 5ms/step - loss: 11.1247 - mae: 11.1247 - val_loss: 11.7539 - val_mae: 11.7539
# Epoch 7/200
# 23/23 [==============================] - 0s 4ms/step - loss: 10.9972 - mae: 10.9972 - val_loss: 11.6150 - val_mae: 11.6150
# Epoch 8/200
# 23/23 [==============================] - 0s 4ms/step - loss: 10.8695 - mae: 10.8695 - val_loss: 11.4765 - val_mae: 11.4765
# Epoch 9/200
# 23/23 [==============================] - 0s 4ms/step - loss: 10.7424 - mae: 10.7424 - val_loss: 11.3385 - val_mae: 11.3385
# Epoch 10/200
# 23/23 [==============================] - 0s 5ms/step - loss: 10.6157 - mae: 10.6157 - val_loss: 11.2001 - val_mae: 11.2001
# Epoch 11/200
# 23/23 [==============================] - 0s 5ms/step - loss: 10.4886 - mae: 10.4886 - val_loss: 11.0615 - val_mae: 11.0615
# Epoch 12/200
# 23/23 [==============================] - 0s 5ms/step - loss: 10.3614 - mae: 10.3614 - val_loss: 10.9242 - val_mae: 10.9242
# Epoch 13/200
# 23/23 [==============================] - 0s 5ms/step - loss: 10.2357 - mae: 10.2357 - val_loss: 10.7870 - val_mae: 10.7870
# Epoch 14/200
# 23/23 [==============================] - 0s 5ms/step - loss: 10.1099 - mae: 10.1099 - val_loss: 10.6481 - val_mae: 10.6481
# Epoch 15/200
# 23/23 [==============================] - 0s 4ms/step - loss: 9.9827 - mae: 9.9827 - val_loss: 10.5111 - val_mae: 10.5111
# Epoch 16/200
# 23/23 [==============================] - 0s 4ms/step - loss: 9.8573 - mae: 9.8573 - val_loss: 10.3734 - val_mae: 10.3734
200
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4297 - val_mae: 2.4297
# Epoch 180/200
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4298 - val_mae: 2.4298
# Epoch 181/200
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4304 - val_mae: 2.4304
# Epoch 182/200
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3594 - mae: 2.3594 - val_loss: 2.4306 - val_mae: 2.4306
# Epoch 183/200
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4307 - val_mae: 2.4307
# Epoch 184/200
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4311 - val_mae: 2.4311
# Epoch 185/200
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4312 - val_mae: 2.4312
# Epoch 186/200
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3593 - mae: 2.3593 - val_loss: 2.4314 - val_mae: 2.4314
# Epoch 187/200
# 23/23 [==============================] - 0s 4ms/step - loss: 2.3594 - mae: 2.3594 - val_loss: 2.4311 - val_mae: 2.4311
# Epoch 188/200
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4316 - val_mae: 2.4316
# Epoch 189/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3594 - mae: 2.3594 - val_loss: 2.4317 - val_mae: 2.4317
# Epoch 190/200
# 23/23 [==============================] - 0s 5ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4318 - val_mae: 2.4318
# Epoch 191/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4317 - val_mae: 2.4317
# Epoch 192/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4316 - val_mae: 2.4316
# Epoch 193/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3594 - mae: 2.3594 - val_loss: 2.4315 - val_mae: 2.4315
# Epoch 194/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3594 - mae: 2.3594 - val_loss: 2.4316 - val_mae: 2.4316
# Epoch 195/200
# 23/23 [==============================] - 0s 7ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4319 - val_mae: 2.4319
# Epoch 196/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3593 - mae: 2.3593 - val_loss: 2.4320 - val_mae: 2.4320
# Epoch 197/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4322 - val_mae: 2.4322
# Epoch 198/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3594 - mae: 2.3594 - val_loss: 2.4322 - val_mae: 2.4322
# Epoch 199/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3595 - mae: 2.3595 - val_loss: 2.4321 - val_mae: 2.4321
# Epoch 200/200
# 23/23 [==============================] - 0s 6ms/step - loss: 2.3593 - mae: 2.3593 - val_loss: 2.4322 - val_mae: 2.4322

# %% [markdown]
# ## Evaluamos el modelo

# %%
# Ploteamos las metricas que se almacenaron en la variable history_slr
pd.DataFrame(history_slr.history).plot(figsize=(10,7));

# %%
# TensorFlow posee el método evaluate
model_0.evaluate(Xtest,ytest)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3713 - mae: 2.3713
# [2.3713035583496094, 2.3713035583496094]

# %% [markdown]
# ## Hacemos una regresión lineal simple con datos nuevos
#
# Para esto usamos el set de Testeo que no se usó durante el entrenamiento

# %%
# Calculamos predicciones y ploteamos
from sklearn import metrics as ms
y_pred = model_0.predict(Xtest)
ms.mean_absolute_error(y_true = ytest, y_pred = y_pred)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 2.371303441204782

# %%
plt.figure(figsize=(10,7))
plt.scatter(Xtest, ytest, c='green', label='Test set')
plt.scatter(Xtest, y_pred, c='orange', label='Prediction set')
plt.legend()
plt.title("Simple Linear Predictions");

# %% [markdown]
# # 2. Regresión lineal multivariante

# %% [markdown]
# ## Armamos el dataset

# %%
data = pd.read_csv('/content/sample_data/california_housing_train.csv')
data.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ## Visualizamos el dataset

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(data.corr(),annot=True,cmap='coolwarm');

# %%
X = data.drop(columns=['housing_median_age','households','median_house_value','latitude','longitude']).to_numpy()
y = data['median_house_value'].to_numpy()

# %%
print(f"Variable de entrada X: {X.shape} | con dimensiones = {X.ndim} | datos tipo: {X.dtype}")
print(f"Variable de salida y: {y.shape} | con dimensiones = {y.ndim} | datos tipo: {y.dtype}")
# Out:
# Variable de entrada X: (17000, 4) | con dimensiones = 2 | datos tipo: float64
# Variable de salida y: (17000,) | con dimensiones = 1 | datos tipo: float64

# %% [markdown]
# ## Separamos el dataset

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=0.15, random_state=42)
Xtrain, Xtest, ytrain, ytest = train_test_split(Xtrain, ytrain, test_size=0.15, random_state=42)

# %%
print(f"Datos de entrenamiento: {Xtrain.shape} | con dimensiones = {Xtrain.ndim} | datos tipo: {Xtrain.dtype}")
print(f"Datos de validacion: {Xval.shape} | con dimensiones = {Xval.ndim} | datos tipo: {Xval.dtype}")
print(f"Datos de testeo: {Xtest.shape} | con dimensiones = {Xtest.ndim} | datos tipo: {Xtest.dtype}")
# Out:
# Datos de entrenamiento: (12282, 4) | con dimensiones = 2 | datos tipo: float64
# Datos de validacion: (2550, 4) | con dimensiones = 2 | datos tipo: float64
# Datos de testeo: (2168, 4) | con dimensiones = 2 | datos tipo: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xval = scaler.fit_transform(Xval)
Xtest = scaler.fit_transform(Xtest)

# %% [markdown]
# ## Construimos la arquitectura de red para regresión

# %%
model_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[4]),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Dense(1,activation='linear')
])
model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1)                 5
#
#  dense_3 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 7 (28.00 Byte)
# Trainable params: 7 (28.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Configuramos el modelo

# %%
model_1.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01),
                loss = tf.keras.losses.mae,
                metrics=['mae'])

# %% [markdown]
# ## Entrenamos el modelo

# %%
history_mlr = model_1.fit(Xtrain,ytrain,
            epochs=200,
            validation_data=(Xval,yval))
# Out:
# Epoch 1/200
# 384/384 [==============================] - 2s 4ms/step - loss: 205548.2031 - mae: 205548.2031 - val_loss: 211586.5781 - val_mae: 211586.5781
# Epoch 2/200
# 384/384 [==============================] - 1s 3ms/step - loss: 205491.6094 - mae: 205491.6094 - val_loss: 211500.5938 - val_mae: 211500.5938
# Epoch 3/200
# 384/384 [==============================] - 1s 3ms/step - loss: 205392.2031 - mae: 205392.2031 - val_loss: 211367.5469 - val_mae: 211367.5469
# Epoch 4/200
# 384/384 [==============================] - 1s 4ms/step - loss: 205250.4531 - mae: 205250.4531 - val_loss: 211187.7500 - val_mae: 211187.7500
# Epoch 5/200
# 384/384 [==============================] - 2s 5ms/step - loss: 205066.5625 - mae: 205066.5625 - val_loss: 210961.4219 - val_mae: 210961.4219
# Epoch 6/200
# 384/384 [==============================] - 1s 4ms/step - loss: 204840.7031 - mae: 204840.7031 - val_loss: 210688.2188 - val_mae: 210688.2188
200
# 384/384 [==============================] - 1s 3ms/step - loss: 73410.2969 - mae: 73410.2969 - val_loss: 76658.6953 - val_mae: 76658.6953
# Epoch 182/200
# 384/384 [==============================] - 1s 3ms/step - loss: 73338.8438 - mae: 73338.8438 - val_loss: 76558.3906 - val_mae: 76558.3906
# Epoch 183/200
# 384/384 [==============================] - 1s 3ms/step - loss: 73260.9922 - mae: 73260.9922 - val_loss: 76455.8906 - val_mae: 76455.8906
# Epoch 184/200
# 384/384 [==============================] - 1s 3ms/step - loss: 73185.8359 - mae: 73185.8359 - val_loss: 76359.7969 - val_mae: 76359.7969
# Epoch 185/200
# 384/384 [==============================] - 1s 3ms/step - loss: 73111.2422 - mae: 73111.2422 - val_loss: 76262.9609 - val_mae: 76262.9609
# Epoch 186/200
# 384/384 [==============================] - 1s 3ms/step - loss: 73036.8438 - mae: 73036.8438 - val_loss: 76165.4922 - val_mae: 76165.4922
# Epoch 187/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72962.8203 - mae: 72962.8203 - val_loss: 76068.8594 - val_mae: 76068.8594
# Epoch 188/200
# 384/384 [==============================] - 1s 4ms/step - loss: 72890.2500 - mae: 72890.2500 - val_loss: 75972.9062 - val_mae: 75972.9062
# Epoch 189/200
# 384/384 [==============================] - 2s 5ms/step - loss: 72817.5156 - mae: 72817.5156 - val_loss: 75875.7109 - val_mae: 75875.7109
# Epoch 190/200
# 384/384 [==============================] - 1s 4ms/step - loss: 72742.3906 - mae: 72742.3906 - val_loss: 75777.6094 - val_mae: 75777.6094
# Epoch 191/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72666.5000 - mae: 72666.5000 - val_loss: 75680.2734 - val_mae: 75680.2734
# Epoch 192/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72593.7422 - mae: 72593.7422 - val_loss: 75587.5547 - val_mae: 75587.5547
# Epoch 193/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72520.8828 - mae: 72520.8828 - val_loss: 75491.9609 - val_mae: 75491.9609
# Epoch 194/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72446.1484 - mae: 72446.1484 - val_loss: 75395.5312 - val_mae: 75395.5312
# Epoch 195/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72372.2109 - mae: 72372.2109 - val_loss: 75298.1016 - val_mae: 75298.1016
# Epoch 196/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72298.6484 - mae: 72298.6484 - val_loss: 75204.2578 - val_mae: 75204.2578
# Epoch 197/200
# 384/384 [==============================] - 1s 4ms/step - loss: 72224.6875 - mae: 72224.6875 - val_loss: 75106.5000 - val_mae: 75106.5000
# Epoch 198/200
# 384/384 [==============================] - 2s 5ms/step - loss: 72150.9531 - mae: 72150.9531 - val_loss: 75009.6719 - val_mae: 75009.6719
# Epoch 199/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72077.9844 - mae: 72077.9844 - val_loss: 74916.3438 - val_mae: 74916.3438
# Epoch 200/200
# 384/384 [==============================] - 1s 3ms/step - loss: 72005.0469 - mae: 72005.0469 - val_loss: 74817.9453 - val_mae: 74817.9453

# %% [markdown]
# ## Evaluamos el modelo

# %%
# Ploteamos las metricas que se almacenaron en la variable history_slr
metrics = pd.DataFrame(history_mlr.history)
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.plot(metrics['loss'],marker = '*',color='blue',label='loss')
plt.plot(metrics['val_loss'],marker = '<',color='orange',label='val_loss')
plt.legend()
plt.subplot(1,2,2)
plt.plot(metrics['mae'],marker = '*',color='purple',label='mae')
plt.plot(metrics['val_mae'],marker = '<',color='yellow',label='val_mae')
plt.legend();

# %%
#Evaluamos el modelo usando el metodo evaluate()
model_1.evaluate(Xtest,ytest)
# Out:
# 68/68 [==============================] - 0s 2ms/step - loss: 75065.4766 - mae: 75065.4766
# [75065.4765625, 75065.4765625]

# %% [markdown]
# ## Optimizamos el modelo de regresión multivariante
#
# Las formas de optimizar un modelo son mediante el ajuste de hiperparametros que controlan el *aprendizaje*. Este proceso resulta que es experimental dependiendo el tipo de problema, si bien hay ciertos patrones que se siguen, el ajuste de hiperparametros resulta casi un `arte`. Algunos de estos ajustes pueden ser:
# * Cantidad de neuronas por capa.
# * Cantidad de capas ocultas.
# * El valor de learning rate.
# * El método de descenso de gradiente.
# * Función de activación.

# %%
# Creamos una nueva arquitectura con más neuronas, capas y funciones de activación
model_1_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[4]),
    tf.keras.layers.Dense(10,activation='relu'),
    tf.keras.layers.Dense(10,activation='relu'),
    tf.keras.layers.Dense(1,activation='linear' )
])
model_1_1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                50
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_1_1.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01),
                loss = tf.keras.losses.mae,
                metrics=['mae'])
history_mlr_1 = model_1_1.fit(Xtrain,ytrain,
            epochs=80,
            validation_data=(Xval,yval))
# Out:
# Epoch 1/80
# 384/384 [==============================] - 3s 4ms/step - loss: 204757.1875 - mae: 204757.1875 - val_loss: 208446.0469 - val_mae: 208446.0469
# Epoch 2/80
# 384/384 [==============================] - 1s 4ms/step - loss: 196381.2812 - mae: 196381.2812 - val_loss: 191072.7031 - val_mae: 191072.7031
# Epoch 3/80
# 384/384 [==============================] - 1s 4ms/step - loss: 169978.7344 - mae: 169978.7344 - val_loss: 148367.4219 - val_mae: 148367.4219
# Epoch 4/80
# 384/384 [==============================] - 1s 3ms/step - loss: 120483.4453 - mae: 120483.4453 - val_loss: 93919.2422 - val_mae: 93919.2422
# Epoch 5/80
# 384/384 [==============================] - 1s 3ms/step - loss: 83143.6562 - mae: 83143.6562 - val_loss: 83824.4297 - val_mae: 83824.4297
# Epoch 6/80
# 384/384 [==============================] - 2s 5ms/step - loss: 78441.0078 - mae: 78441.0078 - val_loss: 82565.8828 - val_mae: 82565.8828
# Epoch 7/80
# 384/384 [==============================] - 2s 4ms/step - loss: 76979.8203 - mae: 76979.8203 - val_loss: 80623.7891 - val_mae: 80623.7891
# Epoch 8/80
# 384/384 [==============================] - 1s 3ms/step - loss: 75490.9375 - mae: 75490.9375 - val_loss: 78575.3750 - val_mae: 78575.3750
# Epoch 9/80
# 384/384 [==============================] - 1s 4ms/step - loss: 73914.5156 - mae: 73914.5156 - val_loss: 76436.7734 - val_mae: 76436.7734
# Epoch 10/80
# 384/384 [==============================] - 1s 3ms/step - loss: 72254.4297 - mae: 72254.4297 - val_loss: 74227.9375 - val_mae: 74227.9375
# Epoch 11/80
# 384/384 [==============================] - 1s 3ms/step - loss: 70573.4062 - mae: 70573.4062 - val_loss: 72097.1328 - val_mae: 72097.1328
# Epoch 12/80
# 384/384 [==============================] - 2s 4ms/step - loss: 58890.7812 - mae: 58890.7812 - val_loss: 64821.2461 - val_mae: 64821.2461
# Epoch 79/80
# 384/384 [==============================] - 1s 4ms/step - loss: 58873.6914 - mae: 58873.6914 - val_loss: 65811.5234 - val_mae: 65811.5234
# Epoch 80/80
# 384/384 [==============================] - 1s 3ms/step - loss: 58836.4414 - mae: 58836.4414 - val_loss: 65073.5703 - val_mae: 65073.5703

# %%
# Ploteamos las metricas que se almacenaron en la variable history_slr
metrics = pd.DataFrame(history_mlr_1.history)
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.plot(metrics['loss'],marker = '*',color='blue',label='loss')
plt.plot(metrics['val_loss'],marker = '<',color='orange',label='val_loss')
plt.legend()
plt.subplot(1,2,2)
plt.plot(metrics['mae'],marker = '*',color='purple',label='mae')
plt.plot(metrics['val_mae'],marker = '<',color='yellow',label='val_mae')
plt.legend();

# %% [markdown]
# He probado un learning rate (alfa) de 0.01, lo cual ha performado muy bien pero a partir de la epoca 30 empieza a marcarse un *overfitting* que lo podemos observas por la varianza entre los datos de entrenamiento y los de validación que empieza a crecer.

# %% [markdown]
# ## <font color='lightgreen'>Experimentar para optimizar la regresión</font> 🤓
#
# Aún podemos mejorar el `aprendizaje` probando algunos hiperparámetros:
# * Agregando más capas
# * Agregando más neuronas
# * Probar optimizador Adam()
# * Probar más epocas

# %%
#Insertar codigo aquí...

# %% [markdown]
# # 3. Regresión logística (clasificación)
#
# Para este ejercicio creamos un dataset de prueba con sklearn. Este nos crea dos conjuntos de datos para clasificar de forma binaria, pero resulta que no son linealmente separables por lo que tendremos que usar un `Perceptron Multicapa`.

# %% [markdown]
# ## Armamos el dataset

# %%
from sklearn.datasets import make_circles
X,y = make_circles(n_samples=1000, factor=0.1,noise=0.1,random_state=42)

# %%
print(f"Variable de entrada X: {X.shape} | con dimensiones = {X.ndim} | datos tipo: {X.dtype}")
print(f"Variable de salida y: {y.shape} | con dimensiones = {y.ndim} | datos tipo: {y.dtype}")
# Out:
# Variable de entrada X: (1000, 2) | con dimensiones = 2 | datos tipo: float64
# Variable de salida y: (1000,) | con dimensiones = 1 | datos tipo: int64

# %%
X[:2]
# Out:
# array([[0.0363413 , 0.10210926],
#        [0.01196432, 0.09342753]])

# %%
set(y) #Estas son las dos clases que posee el dataset [0,1]
# Out:
# {0, 1}

# %% [markdown]
# ## Visualizamos el dataset

# %%
plt.figure(figsize=(15,7))
plt.scatter(X[:,0],X[:,1],c=y,cmap='coolwarm');

# %%
sns.displot(y,color='orange');

# %% [markdown]
# ## Separamos el dataset

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=0.15, random_state=42)
Xtrain, Xtest, ytrain, ytest = train_test_split(Xtrain, ytrain, test_size=0.15, random_state=42)

# %%
print(f"Datos de entrenamiento: {Xtrain.shape} | con dimensiones = {Xtrain.ndim} | datos tipo: {Xtrain.dtype}")
print(f"Datos de validacion: {Xval.shape} | con dimensiones = {Xval.ndim} | datos tipo: {Xval.dtype}")
print(f"Datos de testeo: {Xtest.shape} | con dimensiones = {Xtest.ndim} | datos tipo: {Xtest.dtype}")
# Out:
# Datos de entrenamiento: (722, 2) | con dimensiones = 2 | datos tipo: float64
# Datos de validacion: (150, 2) | con dimensiones = 2 | datos tipo: float64
# Datos de testeo: (128, 2) | con dimensiones = 2 | datos tipo: float64

# %%
Xtrain.min(), Xtrain.max()
# Out:
# (-1.257778829864198, 1.1579379736809112)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.histplot(ytrain,color='orange')
plt.subplot(1,3,2)
sns.histplot(ytest,color='green')
plt.subplot(1,3,3)
sns.histplot(yval,color='purple');

# %% [markdown]
# ## Construimos la arquitectura de red para clasificación

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[2]),
    tf.keras.layers.Dense(4,activation='relu'),
    tf.keras.layers.Dense(4,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid'),
])
model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 4)                 12
#
#  dense_8 (Dense)             (None, 4)                 20
#
#  dense_9 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 37 (148.00 Byte)
# Trainable params: 37 (148.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Configuramos el modelo

# %%
model_2.compile(optimizer = tf.keras.optimizers.Adam(),# RMSprop(),Adagrad()
                loss = tf.keras.losses.BinaryCrossentropy(),
                metrics = ['accuracy'])

# %% [markdown]
# ## Entrenamos el modelo

# %%
history_clasifier = model_2.fit(Xtrain,ytrain,
                                epochs=50,
                                validation_data=(Xval,yval)) #batch_size=16 hiperparametro
# Out:
# Epoch 1/50
# 23/23 [==============================] - 2s 12ms/step - loss: 0.7194 - accuracy: 0.4861 - val_loss: 0.7209 - val_accuracy: 0.4133
# Epoch 2/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7130 - accuracy: 0.3310 - val_loss: 0.7127 - val_accuracy: 0.3067
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7062 - accuracy: 0.2368 - val_loss: 0.7046 - val_accuracy: 0.1400
# Epoch 4/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6985 - accuracy: 0.3463 - val_loss: 0.6929 - val_accuracy: 0.6533
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.8019 - val_loss: 0.6809 - val_accuracy: 0.8667
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6779 - accuracy: 0.8560 - val_loss: 0.6709 - val_accuracy: 0.8733
# Epoch 7/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6696 - accuracy: 0.8338 - val_loss: 0.6614 - val_accuracy: 0.8733
# Epoch 8/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6613 - accuracy: 0.8421 - val_loss: 0.6518 - val_accuracy: 0.8733
# Epoch 9/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6525 - accuracy: 0.8463 - val_loss: 0.6421 - val_accuracy: 0.8800
# Epoch 10/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6434 - accuracy: 0.8421 - val_loss: 0.6317 - val_accuracy: 0.8800
# Epoch 11/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6339 - accuracy: 0.7812 - val_loss: 0.6206 - val_accuracy: 0.7600
# Epoch 12/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6237 - accuracy: 0.8310 - val_loss: 0.6095 - val_accuracy: 0.8800
# Epoch 13/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6132 - accuracy: 0.7992 - val_loss: 0.5975 - val_accuracy: 0.8800
# Epoch 14/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6023 - accuracy: 0.7216 - val_loss: 0.5854 - val_accuracy: 0.7600
# Epoch 15/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5908 - accuracy: 0.7050 - val_loss: 0.5728 - val_accuracy: 0.7600
# Epoch 16/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5791 - accuracy: 0.8324 - val_loss: 0.5598 - val_accuracy: 0.8867
# Epoch 17/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5666 - accuracy: 0.8296 - val_loss: 0.5460 - val_accuracy: 0.8933
# Epoch 18/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5531 - accuracy: 0.7438 - val_loss: 0.5314 - val_accuracy: 0.7933
# Epoch 19/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5385 - accuracy: 0.8864 - val_loss: 0.5158 - val_accuracy: 0.9533
# Epoch 20/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5223 - accuracy: 0.9391 - val_loss: 0.4979 - val_accuracy: 0.9667
# Epoch 21/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5006 - accuracy: 0.9557 - val_loss: 0.4754 - val_accuracy: 0.9867
# Epoch 22/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4764 - accuracy: 0.9792 - val_loss: 0.4541 - val_accuracy: 0.9933
# Epoch 23/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4535 - accuracy: 0.9958 - val_loss: 0.4333 - val_accuracy: 0.9933
# Epoch 24/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4309 - accuracy: 0.9972 - val_loss: 0.4126 - val_accuracy: 0.9933
# Epoch 25/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4087 - accuracy: 0.9986 - val_loss: 0.3921 - val_accuracy: 1.0000
# Epoch 26/50
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3870 - accuracy: 0.9986 - val_loss: 0.3718 - val_accuracy: 1.0000
# Epoch 27/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.3659 - accuracy: 0.9986 - val_loss: 0.3525 - val_accuracy: 1.0000
# Epoch 28/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3454 - accuracy: 0.9986 - val_loss: 0.3336 - val_accuracy: 1.0000
# Epoch 29/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.3256 - accuracy: 0.9986 - val_loss: 0.3154 - val_accuracy: 1.0000
# Epoch 30/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3066 - accuracy: 1.0000 - val_loss: 0.2981 - val_accuracy: 1.0000
# Epoch 31/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2883 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 1.0000
# Epoch 32/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2709 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 1.0000
# Epoch 33/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2544 - accuracy: 1.0000 - val_loss: 0.2504 - val_accuracy: 1.0000
# Epoch 34/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2388 - accuracy: 1.0000 - val_loss: 0.2361 - val_accuracy: 1.0000
# Epoch 35/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2240 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 1.0000
# Epoch 36/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2103 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 1.0000
# Epoch 37/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1973 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 1.0000
# Epoch 38/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1852 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 1.0000
# Epoch 39/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 1.0000 - val_loss: 0.1767 - val_accuracy: 1.0000
# Epoch 40/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1633 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 1.0000
# Epoch 41/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1537 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 1.0000
# Epoch 42/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1443 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 1.0000
# Epoch 43/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1359 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 1.0000
# Epoch 44/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1280 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 1.0000
# Epoch 45/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1207 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 1.0000
# Epoch 46/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1138 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 1.0000
# Epoch 47/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1075 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 1.0000
# Epoch 48/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1016 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 1.0000
# Epoch 49/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0962 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 1.0000
# Epoch 50/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0911 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 1.0000

# %% [markdown]
# ## Evaluamos el modelo

# %%
# Ploteamos las metricas que se almacenaron en la variable history_slr
metrics = pd.DataFrame(history_clasifier.history)
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.plot(metrics['loss'],marker = '*',color='blue',label='loss')
plt.plot(metrics['accuracy'],marker = '<',color='orange',label='accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.title("Train Metrics")
plt.subplot(1,2,2)
plt.plot(metrics['val_loss'],marker = '*',color='purple',label='val_loss')
plt.plot(metrics['val_accuracy'],marker = '<',color='yellow',label='val_accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.title("Validation Metrics");

# %%
model_2.evaluate(Xtest,ytest)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0867 - accuracy: 1.0000
# [0.08672970533370972, 1.0]

# %% [markdown]
# ## Predicción

# %%
from sklearn import metrics as ms
# Hacemos predicciones en base al set de testeo
y_pred = tf.round(tf.squeeze(model_2.predict(Xtest))).numpy()
y_pred[:5]
# Out:
# 4/4 [==============================] - 0s 2ms/step
# array([1., 0., 0., 0., 1.], dtype=float32)

# %%
acc = ms.accuracy_score(ytest, y_pred)
precision = ms.precision_score(ytest, y_pred)
recall = ms.recall_score(ytest, y_pred)
f1_score = ms.f1_score(ytest,y_pred)

log_reg_metrics = {"Accuracy":acc,
                   "Precision":precision,
                   "Recall":recall,
                   "F1":f1_score}
log_reg_metrics
# Out:
# {'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'F1': 1.0}

# %%
# Ploteamos las predicciones
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.scatter(X[:,0],X[:,1],c=y,cmap='coolwarm')
plt.title("Datos de entrenamiento")
plt.subplot(1,2,2)
plt.scatter(Xtest[:,0],Xtest[:,1],c=y_pred,cmap='Dark2')
plt.title("Datos predichos");

# %% [markdown]
# ---

# %% [markdown]
# 🛠 <font style: color='orange'>**Ejercicio Extra:**</font> abajo tienen la implementación de un `perceptron simple` para la tarea de clasificación binaria de pacientes que son diabeticos vs no diabeticos `(0:No, 1:Si)`.
#
# **Tratar** de mejorar las métricas implementando un `perceptrón multicapa`, y probando hiperparámetros hasta lograr métricas óptimas.
#
# Este es un ejercicio personal para que practiquen, **no tiene entrega**. Sin embargo, me pueden compartir por Discord sus resultados o inquietudes que tengan.
#
# Éxitos! 🦾

# %% [markdown]
# >**Nota:** Si quieren investiguen algún dataset para probar sus redes en [Kaggle](https://www.kaggle.com/), allí hay miles de conjuntos de datos.

# %%
# Descargamos el dataset
# !wget https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv

# %%
df = pd.read_csv('diabetes.csv')
df.head()

# %%
X = df.drop(columns='Outcome').to_numpy()
y = df['Outcome'].to_numpy()

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xval, ytrain, yval = train_test_split(X, y, test_size=0.15, random_state=42)
Xtrain, Xtest, ytrain, ytest = train_test_split(Xtrain, ytrain, test_size=0.15, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xval = scaler.fit_transform(Xval)
Xtest = scaler.fit_transform(Xtest)

# %%
model_ps = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[8]),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model_ps.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
              loss = tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])
history_ps = model_ps.fit(Xtrain,ytrain,validation_data=(Xval,yval),epochs=100)

# %%
pd.DataFrame(history_ps.history).plot()
